# %% [markdown]
# <a href="https://colab.research.google.com/github/anukhairnar30/Innomatics-Research-Labs/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. User Login Check**

# %%
# Given credentials
correct_username = "admin"
correct_password = "1234"

# Input (you can change these to test)
#username = "admin"
username = input("Enter Username: ")
#password = "1234"
password = input("Enter Password: ")

# Login check
if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter Username: admin
# Enter Password: 1234
# Login Successful

# %% [markdown]
# **2. Pass / Fail Analyzer**

# %%
# List of student marks
marks = [45, 78, 90, 33, 60]

# Initialize counters for pass and fail students
pass_count = 0
fail_count = 0

# Loop through each student's marks
for mark in marks:

    # Check if student passed (marks ≥ 50)
    if mark >= 50:
        pass_count += 1   # Increase pass count
    else:
        fail_count += 1   # Increase fail count

# Print final results
print("Total Students:", len(marks))
print("Number of Pass Students:", pass_count)
print("Number of Fail Students:", fail_count)
# Out:
# Total Students: 5
# Number of Pass Students: 3
# Number of Fail Students: 2

# %% [markdown]
# **3. Simple Data Cleaner**

# %%
# Given list of names
names = [" Alice ", "bob", " CHARLIE "]

# Create empty list for cleaned names
cleaned_names = []

# Loop through each name
for name in names:
    # Remove extra spaces using strip()
    # Convert to lowercase using lower()
    cleaned_name = name.strip().lower()

    # Add cleaned name to new list
    cleaned_names.append(cleaned_name)

# Print cleaned list
print("Cleaned Names:", cleaned_names)
# Out:
# Cleaned Names: ['alice', 'bob', 'charlie']

# %% [markdown]
# **4. Message Length Analyzer**

# %%
# Given list of messages
messages = ["Hi", "Welcome to the platform", "OK"]

# Loop through each message
for message in messages:

    # Calculate length of message
    length = len(message)

    # Print message and its length
    print(f"Message: '{message}'")
    print("Length:", length)

    # Check if message is longer than 10 characters
    if length > 10:
        print("⚠️ This message is longer than 10 characters.")

    print()  # Empty line for readability
# Out:
# Message: 'Hi'
# Length: 2
#
# Message: 'Welcome to the platform'
# Length: 23
# ⚠️ This message is longer than 10 characters.
#
# Message: 'OK'
# Length: 2

# %% [markdown]
# **5. Error Message Detector**

# %%
# Given system logs
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

# Initialize error counter
error_count = 0

# Loop through each log entry
for log in logs:

    # Check if log entry is "ERROR"
    if log == "ERROR":
        error_count += 1   # Increase error counter

# Print total number of ERROR entries
print("Total ERROR entries:", error_count)
# Out:
# Total ERROR entries: 2
